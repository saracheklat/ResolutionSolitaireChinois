# %% [markdown]
# <a href="https://colab.research.google.com/github/saracheklat/ResolutionSolitaireChinois/blob/master/credit_card_fraud.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importing the Dependencies

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
#loading the dataet to a Pandas DataFrame
credit_card_data = pd.read_csv('/creditcard.csv')

# %%
#first 5 rows of the dataset
credit_card_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
credit_card_data.tail()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 204076  135100.0  2.126725 -0.105402 -1.510722  0.165252  0.376540 -0.534798
# 204077  135100.0 -0.582696  2.109869  0.699058  4.350850  0.524572  0.436313
# 204078  135101.0  1.988614 -0.207240 -0.259236  0.440332 -0.592331 -0.694481
# 204079  135102.0  1.862102 -0.124052 -1.989752  0.382609  0.473032 -0.674517
# 204080  135102.0  0.245859  0.925437 -0.542877 -0.891049  1.585514  0.074328
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 204076  0.131359 -0.228139  0.648901  ... -0.355017 -0.888680  0.220120
# 204077  0.671204  0.087439 -1.980439  ... -0.131965 -0.288737  0.194044
# 204078 -0.372261 -0.152909  1.108784  ... -0.170658 -0.280954  0.351013
# 204079  0.298621 -0.282416  0.802053  ... -0.204158 -0.511441  0.077874
# 204080  1.095022 -0.146891 -0.213699  ...       NaN       NaN       NaN
#
# ...

# %%
credit_card_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 204081 entries, 0 to 204080
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    204081 non-null  float64
#  1   V1      204081 non-null  float64
#  2   V2      204081 non-null  float64
#  3   V3      204081 non-null  float64
#  4   V4      204081 non-null  float64
#  5   V5      204081 non-null  float64
#  6   V6      204081 non-null  float64
#  7   V7      204081 non-null  float64
#  8   V8      204081 non-null  float64
#  9   V9      204081 non-null  float64
#  10  V10     204081 non-null  float64
#  11  V11     204081 non-null  float64
#  12  V12     204080 non-null  float64
#  13  V13     204080 non-null  float64
#  14  V14     204080 non-null  float64
#  15  V15     204080 non-null  float64
#  16  V16     204080 non-null  float64
#  17  V17     204080 non-null  float64
#  18  V18     204080 non-null  float64
#  19  V19     204080 non-null  float64
# ...

# %%
#cheking the number of misssing values in each coloms
credit_card_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       1
# V13       1
# V14       1
# V15       1
# V16       1
# V17       1
# V18       1
# V19       1
# V20       1
# V21       1
# V22       1
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %%
#distribution of legit transactions & fraudulent transactions
credit_card_data['Class'].value_counts()
# Out:
# Class
# 0.0    203688
# 1.0       392
# Name: count, dtype: int64

# %% [markdown]
# This dataset is highly unbalanced

# %% [markdown]
# 0--> Normal Transaction

# %% [markdown]
# 1--> fraudulent transaction

# %%
#separating the data for analysis
legit = credit_card_data[credit_card_data.Class == 0]
fraud = credit_card_data[credit_card_data.Class == 1]

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (203688, 31)
# (392, 31)

# %%
#statistical measures of the data
legit.Amount.describe()
# Out:
# count    203688.000000
# mean         89.698841
# std         248.388033
# min           0.000000
# 25%           5.990000
# 50%          23.000000
# 75%          79.190000
# max       19656.530000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     392.000000
# mean      123.485765
# std       257.455297
# min         0.000000
# 25%         1.000000
# 50%        12.310000
# 75%       105.915000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
#compare the values for both transactions
credit_card_data.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0.0    71931.358926 -0.085236 -0.006647  0.310657  0.061002 -0.094003
# 1.0    62596.510204 -5.586024  4.158763 -7.671289  4.751863 -4.024293
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.045763 -0.032985  0.012967  0.013841  ...  0.017287 -0.014904
# 1.0   -1.396896 -6.519177  0.663336 -2.750902  ...  0.395749  0.777634
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.042991 -0.014317  0.004019  0.057168  0.005541  0.001063  0.001671
# 1.0   -0.016690 -0.047536 -0.065304  0.066588  0.038878  0.181626  0.059742
#
#            Amount
# Class
# 0.0     89.698841
# 1.0    123.485765
#
# [2 rows x 30 columns]

# %% [markdown]
# Under_Sampling

# %% [markdown]
# Build a sample dataset containing similar distribution of legit transactions and Fraudulent Transacitons

# %% [markdown]
# Number of Fraudulent Transactions -->392

# %%
legit_sample = legit.sample(n = 392)

# %% [markdown]
# Concatenating two DataFrames

# %%
new_dataset = pd.concat([legit_sample, fraud],axis = 0)

# %%
new_dataset.head()
# Out:
#           Time        V1        V2        V3        V4        V5        V6  \
# 64198  51073.0 -2.005837 -1.364588  1.241673 -4.053707 -0.895938 -0.797719
# 38398  39381.0 -0.985817  1.289103  0.912891  0.002606  0.098831 -1.085039
# 49465  44073.0 -0.817273  0.556360  1.752672  0.117231  0.235176 -0.259949
# 1210     938.0 -1.774069  1.643783  1.174500  1.121534  0.006667 -0.198686
# 48192  43536.0  0.297102 -1.265646  0.344664  1.248294 -0.664670  0.744235
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 64198 -0.338758  0.570112  1.116506  ... -0.379452 -0.926195 -0.027885
# 38398  1.122052  0.185458 -0.975194  ... -0.206531 -0.931830  0.154726
# 49465  0.803011 -0.033987 -0.331007  ... -0.157225 -0.467041 -0.178523
# 1210   0.760995 -0.228775  0.825399  ... -0.193503  0.284150 -0.036075
# 48192  0.022436  0.258457  0.050223  ...  0.481063  0.544794 -0.386805
#
#             V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
new_dataset.tail()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 203324  134766.0 -0.079653  3.222010 -3.724201  6.037345  0.583395 -0.691346
# 203328  134769.0 -0.967767  2.098019 -5.222929  6.514573 -4.187674  2.114178
# 203700  134928.0  1.204934  3.238070 -6.010324  5.720847  1.548400 -2.321064
# 204064  135095.0  0.232512  0.938944 -4.647780  3.079844 -1.902655 -1.041408
# 204079  135102.0  1.862102 -0.124052 -1.989752  0.382609  0.473032 -0.674517
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 203324 -1.799885 -2.627781 -4.001338  ... -0.664694  1.138556 -0.350753
# 203328  0.948701 -2.448427 -3.203666  ... -0.843268  0.796739  1.314312
# 203700 -0.781880  0.076619 -2.976249  ...  0.098341 -0.845866 -0.031228
# 204064 -1.020407  0.547069 -1.105990  ...  0.911373  1.042929  0.999394
# 204079  0.298621 -0.282416  0.802053  ... -0.204158 -0.511441  0.077874
#
# ...

# %%
new_dataset['Class'].value_counts()
# Out:
# Class
# 0.0    392
# 1.0    392
# Name: count, dtype: int64

# %%
new_dataset.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0.0    72148.767857 -0.164932  0.036145  0.342065  0.012712 -0.063342
# 1.0    62596.510204 -5.586024  4.158763 -7.671289  4.751863 -4.024293
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0   -0.038464 -0.039610 -0.007884  0.011011  ...  0.056218  0.010186
# 1.0   -1.396896 -6.519177  0.663336 -2.750902  ...  0.395749  0.777634
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.060851 -0.003119  0.000239  0.023213  0.039423 -0.005246 -0.004341
# 1.0   -0.016690 -0.047536 -0.065304  0.066588  0.038878  0.181626  0.059742
#
#            Amount
# Class
# 0.0     78.853546
# 1.0    123.485765
#
# [2 rows x 30 columns]

# %% [markdown]
# Splitting the data into Features & Targets

# %%
X = new_dataset.drop(columns = 'Class', axis = 1) #supprimer la colonne Class
Y = new_dataset['Class']

# %%
print(X)
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 64198    51073.0 -2.005837 -1.364588  1.241673 -4.053707 -0.895938 -0.797719
# 38398    39381.0 -0.985817  1.289103  0.912891  0.002606  0.098831 -1.085039
# 49465    44073.0 -0.817273  0.556360  1.752672  0.117231  0.235176 -0.259949
# 1210       938.0 -1.774069  1.643783  1.174500  1.121534  0.006667 -0.198686
# 48192    43536.0  0.297102 -1.265646  0.344664  1.248294 -0.664670  0.744235
# ...          ...       ...       ...       ...       ...       ...       ...
# 203324  134766.0 -0.079653  3.222010 -3.724201  6.037345  0.583395 -0.691346
# 203328  134769.0 -0.967767  2.098019 -5.222929  6.514573 -4.187674  2.114178
# 203700  134928.0  1.204934  3.238070 -6.010324  5.720847  1.548400 -2.321064
# 204064  135095.0  0.232512  0.938944 -4.647780  3.079844 -1.902655 -1.041408
# 204079  135102.0  1.862102 -0.124052 -1.989752  0.382609  0.473032 -0.674517
#
# ...

# %%
print(Y)
# Out:
# 64198     0.0
# 38398     0.0
# 49465     0.0
# 1210      0.0
# 48192     0.0
#          ...
# 203324    1.0
# 203328    1.0
# 203700    1.0
# 204064    1.0
# 204079    1.0
# Name: Class, Length: 784, dtype: float64

# %% [markdown]
# Split the data into Training data & Testing Data

# %%
X_train,X_test, Y_train, Y_test = train_test_split(X, Y,test_size = 0.2, stratify = Y, random_state = 2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (784, 30) (627, 30) (157, 30)

# %% [markdown]
# Model training

# %% [markdown]
# Logistic Regression

# %%
model = LogisticRegression(solver='newton-cg', max_iter = 500)

# %%
# Trainning the Logistic regression model with Training Data
model.fit(X_train,Y_train)
# Out:
# LogisticRegression(max_iter=500, solver='newton-cg')

# %% [markdown]
# Model Evaluation

# %% [markdown]
# Accuracy Score

# %%
# accuracy on training data
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
print('Accuracy on Training data : ', training_data_accuracy)
# Out:
# Accuracy on Training data :  0.9665071770334929

# %%
#accuracy on test data
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction,Y_test)

# %%
print('Accuracy score on Test Data : ', test_data_accuracy)
# Out:
# Accuracy score on Test Data :  0.9299363057324841
